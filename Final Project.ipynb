# %% [markdown]
# # Final Project
#
# The final project is an exploration _and implementation_ of a numerical algorithm of your choice. Typically this will be algorithm that we did not cover in class or an extended/improved version of an algorithm that we did cover, although these are not the only choices.
#
# You have considerable leeway in choosing a topic of interest to you and structuring your report in a way that is appropriate for the topic you choose, but your project  must incorporate all of the following elements:
#
# - Some discussion of the origins and history of the algorithm you discuss. Who invented (or discovered) it, when, and what was the original motivation for the invention or discovery?
#
# - A technical mathematical discussion of the theoretical underpinnings of the algorithm. The level of rigor here should be roughly commensurate with the style of the lecture notes: You do not need to provide fully rigorous proofs of every statement, but the presentation should follow a solid logical sequence in which one idea flows from the next.
#
# - An implementation, in any programming language you like, of some version of the algorithm you discuss. This does not have to be a sophisticated code suitable for use in cutting-edge research, and it does not have to be optimized for efficiency — in fact, it can be a fairly simpleminded implementation — but it must be capable of generating at least some results relevant for the problem at hand.
#
# - Results (including plots) showing the performance of your implementation, and (where possible) comparing it against other implementations.
#
# A rough guideline for the magnitude of the writeup is that it should consist of 10-15 $\LaTeX$ pages (including plots but not including code listings).
#
# ### The final project proposal
#
# Before getting started on your final project, you must submit a brief _proposal_ to let me know what you are planning
# to do and how you envision structuring your final report. This proposal is due by ** November 4, 2016 ** (you may email it to me directly or submit it in class). Below is a rough sample of what a reasonable proposal might
# look like.
#
# > ** Practical Evaluation of Lattice Sums: Is Ewald Summation
# > Always Best? **
# >
# >Many problems in computational science require efficient
# and accurate evaluation of _lattice sums_ — that
# is, sums that accumulate contributions to some physical
# quantity from sites in a one-, two-, or three-dimensional
# lattice. Brute-force evaluation of such sums is generally
# prohibitively expensive, and this fact has spurred the
# development of more sophisticated and efficient methods.
# In class we covered one such method — _Ewald summation_ — but
# we discussed only the electrostatic (zero-frequency) case,
# and then only for the cases of one- and two-dimensional
# lattices.  My final project will extend this discussion
# to a broader comparison of lattice-summation methods,
# including consideration of three-dimensional lattices
# and nonzero-frequency problems.
# >
# >My paper will begin with a brief introduction (2—4
# pages) to the problem. I will then discuss (3—5 pages)
# the history of lattice-summation methods, touching in
# particular on the original contributions of Paul Ewald
# himself and the physical problems that motivated
# his development of the Ewald-summation technique,
# but considering also the evolution of techniques
# spurred by the computer-aided-design (CAD) revolution
# of the late 20th century.
# >
# >Then I will explain (5-8 pages) the mathematical
# underpinnings of several sophisticated lattice-summation
# methods, including **(1)** Ewald summation,
# **(2)** Kummer decomposition, and
# **(3)** integral transforms.
# >
# >Finally, for the specific problem of a 2D lattice sum
# at nonzero frequency I will implement Ewald summation
# and Kummer decomposition and compare (3—5 pages)
# the accuracy and efficiency of these two methods.
#
# ### How the final project is graded
#
# Your most important task in the final project is to get your implementation of the algorithm(s) working
# and produce convincing numerical results (plots, data tables, etc.) that demonstrate that your implementation is
# successful.
#
# Thorough discussions of background, theory, and implementation are also important, but even the
# most thorough treatment of these topics will not compensate for incomplete implementation or a failure to report
# results produced by your original implementation.
#
# A rough grading rubric for the final project looks something like this.
#
# <p align="center">
# <table align="center" border="1">
#  <tr><th> If your project report contains</th>
#      <th> Then your grade can be as high as</th>
#  </tr>
#  <tr><td>
#      <ul>
#      <li> A code listing of your implementation
#      <li> A thorough presentation (plots, data tables, etc.)
#           of results produced by your code
#      <li> A thorough discussion of background, theory, and
#           implementation technicalities
#      </ul>
#      </td>
#      <td align="center">100%</td>
#  </tr>
#  <tr><td>
#      <ul>
#      <li> Code listing
#      <li> Thorough presentation of results
#      <li> Sketchy discussion of background theory
#      </ul>
#      </td>
#      <td align="center">80%</td>
#  </tr>
#  <tr><td>
#      <ul>
#      <li> Code listing
#      <li> Sketchy presentation of results
#      <li> Thorough discussion of background theory
#      </ul>
#      </td>
#      <td align="center">50%</td>
#  </tr>
#  <tr><td>
#      <ul>
#      <li> Little or no presentation of results produced by
#           your code
#      <li> Lengthy discussion of background theory which you
#           attempt to augment with lots of pictures copied
#           from textbooks or websites
#      </td>
#      <td align="center">25%</td>
#  </tr>
# </table>
#
# ## Some Possible Final Projects
#
# Here are a number of possible final-project topics, with content spanning a variety of interesting calculations
# arising in various subfields mathematics.
#
# Needless to say, this is <i>not</i> intended to be an exhaustive list, and in no way are you required to
# choose one of these topics for your project.
#
# ### Numerical Linear Algebra
#
# 1. **Conjugate Gradient Methods for Linear Systems.** Implement the Conjugate Gradient method and test it against other iterative or direct methods on an example problem.
# - **Fast Fourier Transform.** Implement a recursive Fast Fourier Transform in Julia, and test your code against the direct method. Test your code against FFTW, a standard implementation in C. An in-depth reference is Van Loan, “Computational Frameworks for the Fast Fourier Transform.”
# - **The Power Method and Google PageRank.** Implement the power method for finding the leading eigenvector of a matrix. Read and discuss the survey paper “Deeper Inside PageRank” by Langville and Meyer. (This project requires some familiarity with probability and Markov chains.)
# - **K-means clustering via SVD.**  Consider the problem of clustering data into $k$ clusters using the singular value decomposition.
# - **Topic modeling.**  Topic modelling aims to learn the thematic structure of a text corpus automatically.  Possible implementation could be to automatically add metatag data to tweets.
# - **Collaborative Filtering.**  Investigate a recommendation system, which is based on the SVD of sparse matrices.  Illustrate how they complete the recommendation matrix, implement a toy example.
#
# ### Multivariate statistics
#
# Research Principal Components Analysis, and show how it can be used to do multivariate regression and dimension reduction.  If you're eager, look into "Sparse PCA".
#
# ### Chaos in Dynamical Systems: Lorenz Attractor.
#
# Look up the Lorenz Attractor in two or more hard references (books or journal articles.) Use an ODE method to model the system of equations. Change the parameters of the system to display the transition to chaos, and reproduce the “butterfly effect.”
#
#
# ### Computer science / cryptography
#
# Research the Lenstra-Lenstra-Lovasz (LLL) lattice-basis reduction algorithm and its use in proving the fundamental insecurity of knapsack cryptography. You may either **(1)** write your own simple implementation of the LLL algorithm and evaluate its performance on some relevant test cases, or **(2)** write code that calls a pre-existing implementation of the LLL algorithm to implement the steps an unscrupulous eavesdropper would take to decipher a communication that has been supposedly ``encrypted'' using knapsack cryptography.
#
# Here are some references on the LLL algorithm:
#
# - <a href="http://link.springer.com/book/10.1007/978-3-642-02295-1/page/1">The LLL Algorithm: Survey and Applications,</a> edited by Phong Q. Nguyen and Brigitte Valee
# - <a href="http://www.crcnetbase.com/isbn/9781439807026">Lattice Basis Reduction: An Introduction to the LLL Algorithm and its Applications</a>, by Murray R. Bremner
#
#
# ### Pure mathematics
#
# Write a program that computes nontrivial zeros of the Riemann zeta function:
#
# $$\zeta(s) = \sum_{n=1}^\infty \frac{1}{n^s}.$$
#
# Your code should input a height _t_ off the critical line and determine — to arbitrary user-specified accuracy — the location of the nearest zero lying on the critical  line at a height greater than or equal to *t* from the real axis. Use your code to determine the locations of the first 100 nontrivial zeros and compare their spacings to the predictions of random-matrix theory.
